# %%
import pandas as pd
import numpy as np

# %%
playlist = pd.read_csv("./playlist.csv", index_col=0)
playlist.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.773  0.7420    5    -3.678     0       0.0460        0.0206
# 1         0.814  0.6280    7    -7.178     1       0.2210        0.1670
# 2         0.756  0.6970    8    -6.377     1       0.0401        0.1820
# 3         0.712  0.0784    4   -19.067     1       0.0544        0.7390
# 4         0.742  0.6060    7    -6.347     1       0.0362        0.0175
#
#    instrumentalness  liveness  valence  ...  \
# 0           0.00000    0.0754    0.571  ...
# 1           0.00000    0.1010    0.677  ...
# 2           0.00000    0.3330    0.956  ...
# 3           0.00000    0.1070    0.642  ...
# 4           0.00273    0.3420    0.630  ...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/0HqZ...      165265
# 1  https://api.spotify.com/v1/audio-analysis/7mFj...      201334
# 2  https://api.spotify.com/v1/audio-analysis/0QBz...      206071
# 3  https://api.spotify.com/v1/audio-analysis/31fM...      150174
# 4  https://api.spotify.com/v1/audio-analysis/1v8v...      244985
#
#   time_signature                                  song_name  \
# 0              4                                      Bones
# 1              4                               Sweetest Pie
# 2              4                 Bam Bam (feat. Ed Sheeran)
# 3              4  Love You Still (abcdefu romantic version)
# 4              4                               Little Dance
#
#                 artist                                      album  \
# 0      Imagine Dragons                                      Bones
# 1  Megan Thee Stallion                               Sweetest Pie
# 2       Camila Cabello                 Bam Bam (feat. Ed Sheeran)
# 3           Tyler Shaw  Love You Still (abcdefu romantic version)
# 4          Neon Dreams                               Little Dance
#
#                        id                             artist_uri  \
# 0  0HqZX76SFLDz2aW8aiqi7G  spotify:artist:53XhwfbYqKCa1cC15pYq2q
# 1  7mFj0LlWtEJaEigguaWqYh  spotify:artist:181bsRPaVXVlUKXrxwZfHK
# 2  0QBzMgT7NIeoCYy3sJCof1  spotify:artist:4nDoRrQiYLoBzwC5BhVJzF
# 3  31fMJwgrgNdk1IbWZEchX2  spotify:artist:3jERgGiTwNAPxNmDasAb31
# 4  1v8v6lusXvZxmgacuQIr0I  spotify:artist:2UQ6mFkiLYy5VHRJnajQYT
#
#                                               genres  \
# 0                            ['modern rock', 'rock']
# 1  ['dance pop', 'houston rap', 'pop', 'trap queen']
# 2              ['dance pop', 'pop', 'post-teen pop']
# 3                                  ['pop quebecois']
# 4                                   ['canadian pop']
#
#                                               lyrics
# 0  {'lyrics': "Gimme, gimme, gimme some time to t...
# 1  {'lyrics': "(Mano)\r\nYou've never been to Hea...
# 2  {'lyrics': "You said you hated the ocean, but ...
# 3                       {'error': 'No lyrics found'}
# 4                       {'error': 'No lyrics found'}
#
# [5 rows x 24 columns]

# %%
numericColumns = ["danceability", 
            "energy", 
            "loudness", 
            "speechiness", 
            "acousticness", 
            "instrumentalness", 
            "liveness",
            "valence",
            "tempo"]
playlist[numericColumns].mean().values
# Out:
# array([ 6.4296000e-01,  6.5131400e-01, -6.3256600e+00,  8.1960000e-02,
#         1.9955910e-01,  2.0530160e-04,  1.6092600e-01,  5.1589200e-01,
#         1.1958615e+02])
