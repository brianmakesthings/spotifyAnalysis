# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
playlist = pd.read_csv("./spotifydata.csv", index_col=0).dropna()
playlist.head()
# Out:
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0         0.741   0.739  11.0    -4.627   0.0       0.0386      0.005410
# 1         0.649   0.973   6.0    -4.391   1.0       0.0882      0.000639
# 2         0.791   0.862   9.0    -3.240   0.0       0.1100      0.037000
# 3         0.738   0.861   2.0    -4.141   1.0       0.2370      0.318000
# 4         0.647   0.844   0.0    -3.756   1.0       0.0457      0.013700
#
#    instrumentalness  liveness  valence  ...            type  \
# 0          0.026900    0.0496    0.425  ...  audio_features
# 1          0.662000    0.1330    0.221  ...  audio_features
# 2          0.000022    0.0814    0.592  ...  audio_features
# 3          0.001820    0.3250    0.580  ...  audio_features
# 4          0.000658    0.1020    0.746  ...  audio_features
#
#                        id                                   uri  \
# 0  0ikuoejgnBNitqFArW6fFk  spotify:track:0ikuoejgnBNitqFArW6fFk
# ...

# %%
numericColumns = ["danceability", 
            "energy", 
            "loudness", 
            "speechiness", 
            "acousticness", 
            "instrumentalness", 
            "liveness",
            "valence",
            "tempo"]
playlist[numericColumns].mean().values
# Out:
# array([ 5.81626819e-01,  5.40337654e-01, -9.56008197e+00,  7.79365013e-02,
#         3.84654026e-01,  1.91477911e-01,  1.69196034e-01,  4.37820859e-01,
#         1.17381833e+02])

# %%
plt.hist(playlist["loudness"])
# Out:
# (array([  12.,   45.,   90.,  174.,  345.,  504.,  783., 1993., 4538.,
#         1617.]),
#  array([-43.851 , -39.4809, -35.1108, -30.7407, -26.3706, -22.0005,
#         -17.6304, -13.2603,  -8.8902,  -4.5201,  -0.15  ]),
#  <BarContainer object of 10 artists>)
